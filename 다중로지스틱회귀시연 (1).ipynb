# %% [markdown]
# #데이터 훈련

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('./FoodDB.xlsx')
tr_data = df[['식품명','단백질(g)','지방(g)','탄수화물(g)','판단']]

# %%
x = tr_data.iloc[:,1:4]
y = tr_data.iloc[:,4]

# %%
model = Sequential()
model.add(Dense(10,input_dim = 3, activation ='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy')

# %%
history = model.fit(x, y, epochs=5, batch_size=5)

# %%
tr_data

# %% [markdown]
# #데이터 테스트

# %%
test_x2 = np.array([[106,101,121]])
prediction2 = model.predict(test_x2)
print("고칼로리 예상 확률은 %.1f%%입니다." % (prediction2 *100))

# %%
#test_data = pd.read_excel('./Test_data.xlsx')
test_data = tr_data
x_test = test_data.iloc[7702:7703, 1:4].values
predictions = model.predict(x_test)  # 테스트 데이터에 대한 예측 수행
print("고칼로리 예상 확률은 %.1f%%입니다." % (predictions *100))

# %%
x_test
